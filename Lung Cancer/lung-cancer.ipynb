# %% [markdown]
# # Importing libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv('/kaggle/input/lung-cancer-risk-and-trends-across-25-countries/lung_cancer_prediction_dataset.csv')

# %%
data.head(3)
# Out:
#    ID Country  Population_Size  Age Gender Smoker  Years_of_Smoking  \
# 0   0   China             1400   80   Male    Yes                30
# 1   1    Iran               84   53   Male     No                 0
# 2   2  Mexico              128   47   Male    Yes                12
#
#    Cigarettes_per_Day Passive_Smoker Family_History  ...  \
# 0                  29             No             No  ...
# 1                   0            Yes             No  ...
# 2                   6            Yes             No  ...
#
#   Air_Pollution_Exposure Occupational_Exposure  Indoor_Pollution  \
# 0                    Low                   Yes                No
# 1                    Low                   Yes                No
# 2                 Medium                    No                No
#
#   Healthcare_Access Early_Detection Treatment_Type Developed_or_Developing  \
# 0              Poor              No            NaN              Developing
# ...

# %% [markdown]
# # Checking for missing data

# %%
data.isna().sum()
# Out:
# ID                                  0
# Country                             0
# Population_Size                     0
# Age                                 0
# Gender                              0
# Smoker                              0
# Years_of_Smoking                    0
# Cigarettes_per_Day                  0
# Passive_Smoker                      0
# Family_History                      0
# Lung_Cancer_Diagnosis               0
# Cancer_Stage                   211671
# Survival_Years                      0
# Adenocarcinoma_Type                 0
# Air_Pollution_Exposure              0
# Occupational_Exposure               0
# Indoor_Pollution                    0
# Healthcare_Access                   0
# Early_Detection                     0
# Treatment_Type                 213968
# Developed_or_Developing             0
# Annual_Lung_Cancer_Deaths           0
# Lung_Cancer_Prevalence_Rate         0
# Mortality_Rate                      0
# dtype: int64

# %% [markdown]
# # Number of People with Lung Cancer by Country

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Country').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, y='Country', x='count', palette='Spectral')
plt.title('Number of People with Lung Cancer by Country')
plt.xlabel('Number of People with Lung Cancer')
plt.ylabel('Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Smoker

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Smoker').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Smoker', y='count', palette='Spectral')
plt.title('Number of People with Lung Cancer by Smoker')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Smoker')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Health care Access

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Healthcare_Access').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Healthcare_Access', y='count', palette='Spectral')
plt.title('Number of People with Lung Cancer by Health care Access')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Healthcare Access')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Early Detection

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Early_Detection').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Early_Detection', y='count', palette='plasma')
plt.title('Number of People with Lung Cancer by Early Detection')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Early_Detection')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Gender

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    110488
# Male      110144
# Name: count, dtype: int64

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Gender').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Gender', y='count', palette='plasma')
plt.title('Number of People with Lung Cancer by Gender')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Family_History

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Family_History').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Family_History', y='count', palette='viridis')
plt.title('Number of People with Lung Cancer by Family History')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Family History')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Number of People with Lung Cancer by Air Pollution Exposure

# %%
Diagnosis_count = data[data['Lung_Cancer_Diagnosis'] == 'Yes'].groupby('Air_Pollution_Exposure').size().reset_index(name='count')
Diagnosis_count = Diagnosis_count.sort_values(by='count', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=Diagnosis_count, x='Air_Pollution_Exposure', y='count', palette='inferno')
plt.title('Number of People with Lung Cancer by Air Pollution Exposure')
plt.ylabel('Number of People with Lung Cancer')
plt.xlabel('Air Pollution Exposure')
plt.xticks(rotation=0)
plt.show()
